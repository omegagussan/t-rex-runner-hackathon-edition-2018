# %%
import numpy as np

# %%
r = np.load("./data/r-2020-11-04 16:45:52.847281.npy")

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(r)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
q = np.load("./data/q-2020-11-04 16:45:52.847281.npy")
q
# Out:
# array([[  0.        ,   0.        ],
#        [  0.        ,  46.08      ],
#        [  0.        ,   0.        ],
#        ...,
#        [  0.        ,  33.0944    ],
#        [  0.        , 105.15231041],
#        [ 32.33211513,   0.        ]])

# %%
manual_q = np.zeros([600,2])

# %%
import sys

# %%
manual_q[:, 1] = sys.maxsize

# %%
manual_q[0:160, 0] = sys.maxsize

# %%
manual_q[0:160, 1] = 0

# %%
np.save("./data/manual_q.npy", manual_q)

# %%
read_manual_q = np.load("./data/manual_q.npy")

# %%
read_manual_q
# Out:
# array([[9.22337204e+18, 0.00000000e+00],
#        [9.22337204e+18, 0.00000000e+00],
#        [9.22337204e+18, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 9.22337204e+18],
#        [0.00000000e+00, 9.22337204e+18],
#        [0.00000000e+00, 9.22337204e+18]])
